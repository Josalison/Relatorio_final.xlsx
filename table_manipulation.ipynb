# %%
import pandas as pd

# %%
df_excel = pd.read_excel("planilha_preço.xlsx")
df_excel
# Out:
#         Data  ID_Pedido           Produto  Quantidade  Preco_Unitario  \
# 0 2026-06-01       1001          Notebook           1          3500.0
# 1 2026-06-01       1002        Monitor 24           2           900.0
# 2 2026-06-02       1003  Teclado Mecanico           5           250.0
# 3 2026-06-02       1004          Notebook           1          3500.0
# 4 2026-06-03       1005       Mouse Gamer           3           150.0
# 5 2026-06-03       1001          Notebook           1          3500.0
#
#          Regiao
# 0       Sudeste
# 1           Sul
# 2      Nordeste
# 3       Sudeste
# 4  Centro-Oeste
# 5       Sudeste
